# %%
import pandas

# %%
akhil=pandas.read_csv("ABA_2018.csv")

# %%
akhil
# Out:
#                                             Behavior  12/28    1/18  1/11  \
# 0                       Instances of aggression/hour   0.00   0.000     0
# 1                           Inappropriate touch/hour   0.00   0.000     0
# 2                                     Elopement/hour   0.13   0.235     0
# 3  Frequency of Initiating Social Interactions w/...  68.00  94.220    85
# 4    Frequency of Responding to Greetings from Peers  92.80  66.670   100
#
#     1/19   1/26   2/02    2/9   2/16    3/5   ...      4/6    4/13   4/27  \
# 0   0.00   0.56   0.20   0.47   0.56   0.30   ...     0.00    0.23   0.00
# 1   0.44   1.10   0.39   2.31   2.26   1.20   ...     0.53    0.30   0.17
# 2   0.00   0.75   0.00   0.99   0.74   0.11   ...     0.39    0.62   0.26
# 3  85.00  53.80  78.57  61.30  65.80  82.60   ...    94.40  100.00  91.62
# 4  72.00  47.10  80.16  54.00  62.50  59.26   ...    83.34  100.00  94.45
#
#      5/4    5/11   5/18    5/25    6/1    6/8    6/15
# ...

# %%
akhil.to_dict()
# Out:
# {'1/11': {0: 0, 1: 0, 2: 0, 3: 85, 4: 100},
#  '1/18': {0: 0.0, 1: 0.0, 2: 0.235, 3: 94.22, 4: 66.67},
#  '1/19': {0: 0.0, 1: 0.44, 2: 0.0, 3: 85.0, 4: 72.0},
#  '1/26': {0: 0.56, 1: 1.1, 2: 0.75, 3: 53.8, 4: 47.1},
#  '12/28': {0: 0.0, 1: 0.0, 2: 0.13, 3: 68.0, 4: 92.8},
#  '2/02': {0: 0.2, 1: 0.39, 2: 0.0, 3: 78.57, 4: 80.16},
#  '2/16': {0: 0.56, 1: 2.26, 2: 0.74, 3: 65.8, 4: 62.5},
#  '2/9': {0: 0.47, 1: 2.31, 2: 0.99, 3: 61.3, 4: 54.0},
#  '3/16': {0: 0.0, 1: 0.53, 2: 0.36, 3: 90.0, 4: 68.1},
#  '3/23': {0: 0.0, 1: 1.3, 2: 5.13, 3: 91.67, 4: 57.92},
#  '3/30': {0: 0.31, 1: 1.61, 2: 1.5, 3: 77.3, 4: 80.36},
#  '3/5': {0: 0.3, 1: 1.2, 2: 0.11, 3: 82.6, 4: 59.26},
#  '3/9': {0: 0.01, 1: 0.52, 2: 0.19, 3: 89.63, 4: 80.5},
#  '4/13': {0: 0.23, 1: 0.3, 2: 0.62, 3: 100.0, 4: 100.0},
#  '4/27': {0: 0.0, 1: 0.17, 2: 0.26, 3: 91.62, 4: 94.45},
#  '4/6': {0: 0.0, 1: 0.53, 2: 0.39, 3: 94.4, 4: 83.34},
#  '5/11': {0: 0.0, 1: 0.03, 2: 0.24, 3: 83.0, 4: 100.0},
# ...
